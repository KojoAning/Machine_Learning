# %%
import tensorflow as tf
import cv2 as cv
import matplotlib.pyplot as plt
import os
import numpy as np

# %%
Spectr_image = r"C:\Users\ANING\Downloads\Spectrogram"
Spectr_image0 = r"C:\Users\ANING\Downloads\Spectrogram\Spectrogram_0"
Spectr_image1 = r"C:\Users\ANING\Downloads\Spectrogram\Spectrogram_1"

# %%
images = os.listdir(Spectr_image0)

# %%
def crop_image(image):
    imag = np.array(image)
    # print(imag)
    mask = np.zeros(image.shape,dtype=np.uint8)
    cv.rectangle(mask,(100,50),(710,585),(255,255,255),-1)
    image = np.bitwise_and(imag,mask)
    x, y, w, h = 100,50,610,535

    # Crop the image using the bounding rectangle coordinates
    cropped_image = image[y:y + h, x:x + w]
    image =np.array(image)
    return cropped_image

# %%
for images in os.listdir(Spectr_image0):
    img = cv.imread(Spectr_image0+"\\"+images)
    cv.imwrite()

# %%
img = cv.imread(Spectr_image0+"\\"+images[0])

# %%
plt.imshow(img)

# %%
crop_image(img)
